# %%
# 강화학습 라이브러리에서 가져와서 트레이닝하기
# OpenAI에서 Gym 만듦
# OpenAI에서 baselines라고 불리는 강화학습 알고리즘 라이브러리
# stable baselines

# %%
# !git clone https://github.com/DLR-RM/rl-baselines3-zoo

# %%
# !pip install stable-baselines3[extra]
# !pip install gymnasium
# !pip install huggingface_hub
# !pip install huggingface_sb3
# !pip install sb3_contrib
# !pip install optuna
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 3.3 MB/s eta 0:00:00
# Collecting gymnasium==0.28.1 (from stable-baselines3[extra])
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 55.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.12.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.4.2)
# Collecting shimmy[atari]~=0.2.1 (from stable-baselines3[extra])
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.0 (from stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.5.0)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3[extra])
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3[extra]) (4.7.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1->stable-baselines3[extra])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.27.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 45.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=0.2.1->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.41.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2022.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.14.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]) (6.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446659 sha256=bfb38a3e77cac76e772ab5870f64473c0583e6fb728a86ca00c7e6059f4c4e7e
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, jax-jumpy, ale-py, gymnasium, AutoROM.accept-rom-license, autorom, shimmy, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 shimmy-0.2.1 stable-baselines3-2.0.0
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (0.28.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.22.4)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Installing collected packages: huggingface_hub
# Successfully installed huggingface_hub-0.16.4
# Collecting huggingface_sb3
#   Downloading huggingface_sb3-2.2.5-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (0.16.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (6.0.1)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.6 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3) (2.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3) (3.4)
# Installing collected packages: huggingface_sb3
# Successfully installed huggingface_sb3-2.2.5
# Collecting sb3_contrib
#   Downloading sb3_contrib-2.0.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: stable-baselines3>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sb3_contrib) (2.0.0)
# Requirement already satisfied: gymnasium==0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0->sb3_contrib) (0.28.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0->sb3_contrib) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0->sb3_contrib) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0->sb3_contrib) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0->sb3_contrib) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3>=2.0.0->sb3_contrib) (3.7.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0->sb3_contrib) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0->sb3_contrib) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3>=2.0.0->sb3_contrib) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3>=2.0.0->sb3_contrib) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3>=2.0.0->sb3_contrib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3>=2.0.0->sb3_contrib) (1.3.0)
# Installing collected packages: sb3_contrib
# Successfully installed sb3_contrib-2.0.0
# Collecting optuna
#   Downloading optuna-3.2.0-py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.6/390.6 kB 4.9 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.11.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 24.8 MB/s eta 0:00:00
# Collecting cmaes>=0.9.1 (from optuna)
#   Downloading cmaes-0.10.0-py3-none-any.whl (29 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.19)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.7.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.11.1 cmaes-0.10.0 colorlog-6.7.0 optuna-3.2.0

# %%
# !python3 /content/rl-baselines3-zoo/train.py --algo ppo --env CartPole-v1 --eval-episodes 10 --eval-episodes 10000
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# 2023-08-04 11:54:43.004548: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-04 11:54:43.877304: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ========== CartPole-v1 ==========
# Seed: 1230482081
# Loading hyperparameters from: /content/rl-baselines3-zoo/hyperparams/ppo.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 256),
#              ('clip_range', 'lin_0.2'),
#              ('ent_coef', 0.0),
#              ('gae_lambda', 0.8),
#              ('gamma', 0.98),
#              ('learning_rate', 'lin_0.001'),
#              ('n_envs', 8),
#              ('n_epochs', 20),
#              ('n_steps', 32),
#              ('n_timesteps', 100000.0),
#              ('policy', 'MlpPolicy')])
# Using 8 environments
# Creating test environment
# Using cuda device
# Log path: logs/ppo/CartPole-v1_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 16.5     |
# |    ep_rew_mean     | 16.5     |
# | time/              |          |
# |    fps             | 80       |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 256      |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.2         |
# |    ep_rew_mean          | 19.2         |
# | time/                   |              |
# |    fps                  | 150          |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 512          |
# | train/                  |              |
# |    approx_kl            | 0.0042613083 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.199        |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.00183      |
# |    learning_rate        | 0.000997     |
# |    loss                 | 5.29         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 12.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.3        |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 218         |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.012248162 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.199       |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.00116     |
# |    learning_rate        | 0.000995    |
# |    loss                 | 3.5         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.3         |
# |    ep_rew_mean          | 20.3         |
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 4            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0037248298 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.198        |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.0279       |
# |    learning_rate        | 0.000992     |
# |    loss                 | 1.72         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 7.32         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.4         |
# |    ep_rew_mean          | 22.4         |
# | time/                   |              |
# |    fps                  | 339          |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 1280         |
# | train/                  |              |
# |    approx_kl            | 0.0050782645 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.198        |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.104        |
# |    learning_rate        | 0.00099      |
# |    loss                 | 1.48         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00543     |
# |    value_loss           | 6            |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.9        |
# |    ep_rew_mean          | 23.9        |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.006375834 |
# |    clip_fraction        | 0.00371     |
# |    clip_range           | 0.197       |
# |    entropy_loss         | -0.679      |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.000987    |
# |    loss                 | 1.23        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 6.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.8        |
# |    ep_rew_mean          | 24.8        |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 1792        |
# | train/                  |             |
# |    approx_kl            | 0.006348003 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.197       |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | -0.0757     |
# |    learning_rate        | 0.000985    |
# |    loss                 | 3.24        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00377    |
# |    value_loss           | 7.94        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.8         |
# |    ep_rew_mean          | 26.8         |
# | time/                   |              |
# |    fps                  | 494          |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0052810838 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.196        |
# |    entropy_loss         | -0.642       |
# |    explained_variance   | -0.135       |
# |    learning_rate        | 0.000982     |
# |    loss                 | 2.28         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00398     |
# |    value_loss           | 8.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 30          |
# | time/                   |             |
# |    fps                  | 540         |
# |    iterations           | 9           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.003695617 |
# |    clip_fraction        | 0.0174      |
# |    clip_range           | 0.196       |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | -0.0193     |
# |    learning_rate        | 0.00098     |
# |    loss                 | 3.21        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 8           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33.7         |
# |    ep_rew_mean          | 33.7         |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 10           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0034457427 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.195        |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.0548       |
# |    learning_rate        | 0.000977     |
# |    loss                 | 4.27         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.8         |
# |    ep_rew_mean          | 34.8         |
# | time/                   |              |
# |    fps                  | 625          |
# |    iterations           | 11           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 0.0053406497 |
# |    clip_fraction        | 0.0609       |
# |    clip_range           | 0.195        |
# |    entropy_loss         | -0.616       |
# |    explained_variance   | 0.0557       |
# |    learning_rate        | 0.000974     |
# |    loss                 | 4.81         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.006       |
# |    value_loss           | 10.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.8        |
# |    ep_rew_mean          | 38.8        |
# | time/                   |             |
# |    fps                  | 660         |
# |    iterations           | 12          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.010335137 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.194       |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.000972    |
# |    loss                 | 2.15        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00869    |
# |    value_loss           | 6.83        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.8         |
# |    ep_rew_mean          | 38.8         |
# | time/                   |              |
# |    fps                  | 689          |
# |    iterations           | 13           |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0104901455 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.194        |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.0531       |
# |    learning_rate        | 0.000969     |
# |    loss                 | 8.28         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0163      |
# |    value_loss           | 17.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.1        |
# |    ep_rew_mean          | 40.1        |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 14          |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.023538213 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.193       |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.404       |
# |    learning_rate        | 0.000967    |
# |    loss                 | 0.684       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 3.54        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.5         |
# |    ep_rew_mean          | 40.5         |
# | time/                   |              |
# |    fps                  | 747          |
# |    iterations           | 15           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 3840         |
# | train/                  |              |
# |    approx_kl            | 0.0045150174 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.193        |
# |    entropy_loss         | -0.58        |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.000964     |
# |    loss                 | 2.03         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 5.44         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.8        |
# |    ep_rew_mean          | 42.8        |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 16          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005294061 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.192       |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.000962    |
# |    loss                 | 2.22        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 6.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.9        |
# |    ep_rew_mean          | 44.9        |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 17          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.010338977 |
# |    clip_fraction        | 0.0463      |
# |    clip_range           | 0.192       |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.000959    |
# |    loss                 | 0.761       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 2.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.1        |
# |    ep_rew_mean          | 50.1        |
# | time/                   |             |
# |    fps                  | 820         |
# |    iterations           | 18          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.010476658 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.191       |
# |    entropy_loss         | -0.61       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.000956    |
# |    loss                 | 2.7         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00248    |
# |    value_loss           | 6.77        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 51.3         |
# |    ep_rew_mean          | 51.3         |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 19           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4864         |
# | train/                  |              |
# |    approx_kl            | 0.0070449747 |
# |    clip_fraction        | 0.157        |
# |    clip_range           | 0.191        |
# |    entropy_loss         | -0.603       |
# |    explained_variance   | 0.438        |
# |    learning_rate        | 0.000954     |
# |    loss                 | 12.8         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 26           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58.1         |
# |    ep_rew_mean          | 58.1         |
# | time/                   |              |
# |    fps                  | 858          |
# |    iterations           | 20           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0039790114 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.19         |
# |    entropy_loss         | -0.612       |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.000951     |
# |    loss                 | 0.771        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 2.84         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.3        |
# |    ep_rew_mean          | 58.3        |
# | time/                   |             |
# |    fps                  | 878         |
# |    iterations           | 21          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.005105558 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.19        |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.000949    |
# |    loss                 | 9.88        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.3        |
# |    ep_rew_mean          | 58.3        |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 22          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.007324701 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.189       |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.000946    |
# |    loss                 | 9.6         |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00896    |
# |    value_loss           | 19.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 59.5       |
# |    ep_rew_mean          | 59.5       |
# | time/                   |            |
# |    fps                  | 912        |
# |    iterations           | 23         |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 5888       |
# | train/                  |            |
# |    approx_kl            | 0.03375535 |
# |    clip_fraction        | 0.186      |
# |    clip_range           | 0.189      |
# |    entropy_loss         | -0.603     |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.000944   |
# |    loss                 | 0.179      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0183    |
# |    value_loss           | 1.28       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 61.7         |
# |    ep_rew_mean          | 61.7         |
# | time/                   |              |
# |    fps                  | 927          |
# |    iterations           | 24           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0025266407 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.188        |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.000941     |
# |    loss                 | 0.862        |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000503    |
# |    value_loss           | 2.65         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 64.3         |
# |    ep_rew_mean          | 64.3         |
# | time/                   |              |
# |    fps                  | 940          |
# |    iterations           | 25           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0039123436 |
# |    clip_fraction        | 0.0254       |
# |    clip_range           | 0.188        |
# |    entropy_loss         | -0.578       |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.000939     |
# |    loss                 | 6.65         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 14.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.5        |
# |    ep_rew_mean          | 65.5        |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 26          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.015872054 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.187       |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.000936    |
# |    loss                 | 6.84        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 14.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66           |
# |    ep_rew_mean          | 66           |
# | time/                   |              |
# |    fps                  | 964          |
# |    iterations           | 27           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6912         |
# | train/                  |              |
# |    approx_kl            | 0.0042756903 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.187        |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.000933     |
# |    loss                 | 0.691        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00796     |
# |    value_loss           | 2.77         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.6        |
# |    ep_rew_mean          | 69.6        |
# | time/                   |             |
# |    fps                  | 976         |
# |    iterations           | 28          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.007944142 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.186       |
# |    entropy_loss         | -0.562      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.000931    |
# |    loss                 | 0.246       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00765    |
# |    value_loss           | 1.14        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 70.8          |
# |    ep_rew_mean          | 70.8          |
# | time/                   |               |
# |    fps                  | 994           |
# |    iterations           | 29            |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 7424          |
# | train/                  |               |
# |    approx_kl            | 0.00080522045 |
# |    clip_fraction        | 0.0543        |
# |    clip_range           | 0.186         |
# |    entropy_loss         | -0.535        |
# |    explained_variance   | 0.991         |
# |    learning_rate        | 0.000928      |
# |    loss                 | 0.268         |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.00112      |
# |    value_loss           | 1.31          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.5         |
# |    ep_rew_mean          | 71.5         |
# | time/                   |              |
# |    fps                  | 1012         |
# |    iterations           | 30           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 7680         |
# | train/                  |              |
# |    approx_kl            | 0.0020941542 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.185        |
# |    entropy_loss         | -0.542       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.000926     |
# |    loss                 | 0.538        |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 1.76         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.9         |
# |    ep_rew_mean          | 73.9         |
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 31           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 7936         |
# | train/                  |              |
# |    approx_kl            | 0.0012257417 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.185        |
# |    entropy_loss         | -0.549       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.000923     |
# |    loss                 | 0.404        |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00292     |
# |    value_loss           | 1.55         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.5        |
# |    ep_rew_mean          | 77.5        |
# | time/                   |             |
# |    fps                  | 1046        |
# |    iterations           | 32          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.000736451 |
# |    clip_fraction        | 0.00117     |
# |    clip_range           | 0.184       |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.000921    |
# |    loss                 | 0.677       |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.000462   |
# |    value_loss           | 1.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.5        |
# |    ep_rew_mean          | 77.5        |
# | time/                   |             |
# |    fps                  | 1061        |
# |    iterations           | 33          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.013089103 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.184       |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.000918    |
# |    loss                 | 0.352       |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.00561    |
# |    value_loss           | 1.12        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 79.9          |
# |    ep_rew_mean          | 79.9          |
# | time/                   |               |
# |    fps                  | 1078          |
# |    iterations           | 34            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 8704          |
# | train/                  |               |
# |    approx_kl            | 0.00086366665 |
# |    clip_fraction        | 0.0611        |
# |    clip_range           | 0.183         |
# |    entropy_loss         | -0.491        |
# |    explained_variance   | 0.996         |
# |    learning_rate        | 0.000916      |
# |    loss                 | 0.136         |
# |    n_updates            | 660           |
# |    policy_gradient_loss | 0.00363       |
# |    value_loss           | 0.798         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.9         |
# |    ep_rew_mean          | 79.9         |
# | time/                   |              |
# |    fps                  | 1093         |
# |    iterations           | 35           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 8960         |
# | train/                  |              |
# |    approx_kl            | 0.0008681846 |
# |    clip_fraction        | 0.0598       |
# |    clip_range           | 0.183        |
# |    entropy_loss         | -0.501       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.000913     |
# |    loss                 | 0.321        |
# |    n_updates            | 680          |
# |    policy_gradient_loss | -0.00454     |
# |    value_loss           | 0.978        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.9        |
# |    ep_rew_mean          | 81.9        |
# | time/                   |             |
# |    fps                  | 1108        |
# |    iterations           | 36          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.013150748 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.182       |
# |    entropy_loss         | -0.476      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.00091     |
# |    loss                 | 0.0245      |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 0.293       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.7        |
# |    ep_rew_mean          | 83.7        |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 37          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.009833787 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.182       |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.000908    |
# |    loss                 | 0.161       |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 0.476       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 92.1         |
# |    ep_rew_mean          | 92.1         |
# | time/                   |              |
# |    fps                  | 1136         |
# |    iterations           | 38           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 9728         |
# | train/                  |              |
# |    approx_kl            | 0.0075074723 |
# |    clip_fraction        | 0.0945       |
# |    clip_range           | 0.181        |
# |    entropy_loss         | -0.506       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.000905     |
# |    loss                 | 0.129        |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 0.514        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.9         |
# |    ep_rew_mean          | 94.9         |
# | time/                   |              |
# |    fps                  | 1150         |
# |    iterations           | 39           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0062629334 |
# |    clip_fraction        | 0.184        |
# |    clip_range           | 0.181        |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.000903     |
# |    loss                 | 1.26         |
# |    n_updates            | 760          |
# |    policy_gradient_loss | -0.0167      |
# |    value_loss           | 2.92         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.8         |
# |    ep_rew_mean          | 95.8         |
# | time/                   |              |
# |    fps                  | 1164         |
# |    iterations           | 40           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0019273108 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.18         |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0009       |
# |    loss                 | 0.25         |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 1.23         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 100           |
# | time/                   |               |
# |    fps                  | 1176          |
# |    iterations           | 41            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 10496         |
# | train/                  |               |
# |    approx_kl            | 0.00022601895 |
# |    clip_fraction        | 0.0127        |
# |    clip_range           | 0.18          |
# |    entropy_loss         | -0.525        |
# |    explained_variance   | 0.981         |
# |    learning_rate        | 0.000898      |
# |    loss                 | 0.389         |
# |    n_updates            | 800           |
# |    policy_gradient_loss | 0.00652       |
# |    value_loss           | 1.11          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 1188        |
# |    iterations           | 42          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.013699694 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.179       |
# |    entropy_loss         | -0.503      |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.000895    |
# |    loss                 | 3.46        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0162     |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 1201        |
# |    iterations           | 43          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.011167888 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.178       |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.000892    |
# |    loss                 | 0.652       |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 2.36        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 1213        |
# |    iterations           | 44          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.058897987 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.178       |
# |    entropy_loss         | -0.453      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.00089     |
# |    loss                 | 0.402       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 1225        |
# |    iterations           | 45          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 11520       |
# | train/                  |             |
# |    approx_kl            | 0.054346636 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.177       |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.000887    |
# |    loss                 | 0.479       |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 1.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 1233        |
# |    iterations           | 46          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.008786552 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.177       |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.000885    |
# |    loss                 | 2.46        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 6.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 1244        |
# |    iterations           | 47          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 12032       |
# | train/                  |             |
# |    approx_kl            | 0.003199988 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.176       |
# |    entropy_loss         | -0.516      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.000882    |
# |    loss                 | 3.64        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00938    |
# |    value_loss           | 8.28        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 1255         |
# |    iterations           | 48           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0013756123 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.176        |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.00088      |
# |    loss                 | 0.107        |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.00301     |
# |    value_loss           | 0.592        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 1265         |
# |    iterations           | 49           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 0.0106622055 |
# |    clip_fraction        | 0.0912       |
# |    clip_range           | 0.175        |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.000877     |
# |    loss                 | 0.0284       |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00919     |
# |    value_loss           | 0.159        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 50          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.015467792 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.175       |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.000875    |
# |    loss                 | 0.0117      |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 0.137       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 1286        |
# |    iterations           | 51          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 13056       |
# | train/                  |             |
# |    approx_kl            | 0.013673341 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.174       |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.000872    |
# |    loss                 | 0.0258      |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00386    |
# |    value_loss           | 0.256       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 1296         |
# |    iterations           | 52           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0032697152 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.174        |
# |    entropy_loss         | -0.495       |
# |    explained_variance   | 0.886        |
# |    learning_rate        | 0.000869     |
# |    loss                 | 0.0135       |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.00564     |
# |    value_loss           | 0.152        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 1306        |
# |    iterations           | 53          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 13568       |
# | train/                  |             |
# |    approx_kl            | 0.014630421 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.173       |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.000867    |
# |    loss                 | -0.0161     |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 161          |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 1496         |
# |    iterations           | 80           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0051884465 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.16         |
# |    entropy_loss         | -0.429       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.000798     |
# |    loss                 | 0.263        |
# |    n_updates            | 1580         |
# |    policy_gradient_loss | -0.00332     |
# |    value_loss           | 0.695        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 1502         |
# |    iterations           | 81           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 20736        |
# | train/                  |              |
# |    approx_kl            | 0.0014617796 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.159        |
# |    entropy_loss         | -0.439       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.000795     |
# |    loss                 | 0.0319       |
# |    n_updates            | 1600         |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 0.141        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 1508        |
# |    iterations           | 82          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20992       |
# | train/                  |             |
# |    approx_kl            | 0.002746462 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.159       |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.000793    |
# |    loss                 | 0.109       |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 0.37        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 158          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 1513         |
# |    iterations           | 83           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 21248        |
# | train/                  |              |
# |    approx_kl            | 0.0067011295 |
# |    clip_fraction        | 0.0566       |
# |    clip_range           | 0.158        |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.00079      |
# |    loss                 | 0.0296       |
# |    n_updates            | 1640         |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 0.112        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 158          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 1518         |
# |    iterations           | 84           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0043830923 |
# |    clip_fraction        | 0.0705       |
# |    clip_range           | 0.158        |
# |    entropy_loss         | -0.384       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.000788     |
# |    loss                 | 0.0637       |
# |    n_updates            | 1660         |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 0.196        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 1524        |
# |    iterations           | 85          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 21760       |
# | train/                  |             |
# |    approx_kl            | 0.016332539 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.157       |
# |    entropy_loss         | -0.377      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.000785    |
# |    loss                 | 0.0215      |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 0.0735      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 1529         |
# |    iterations           | 86           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22016        |
# | train/                  |              |
# |    approx_kl            | 0.0055901036 |
# |    clip_fraction        | 0.0191       |
# |    clip_range           | 0.156        |
# |    entropy_loss         | -0.412       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.000782     |
# |    loss                 | 0.00421      |
# |    n_updates            | 1700         |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 0.0426       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 1534         |
# |    iterations           | 87           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22272        |
# | train/                  |              |
# |    approx_kl            | 0.0017397832 |
# |    clip_fraction        | 0.198        |
# |    clip_range           | 0.156        |
# |    entropy_loss         | -0.419       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.00078      |
# |    loss                 | 0.13         |
# |    n_updates            | 1720         |
# |    policy_gradient_loss | -0.005       |
# |    value_loss           | 0.304        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 1539        |
# |    iterations           | 88          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006061461 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.155       |
# |    entropy_loss         | -0.404      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.000777    |
# |    loss                 | 0.0415      |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | -0.00455    |
# |    value_loss           | 0.122       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 1544         |
# |    iterations           | 89           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22784        |
# | train/                  |              |
# |    approx_kl            | 0.0037346352 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.155        |
# |    entropy_loss         | -0.407       |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.000775     |
# |    loss                 | -0.00257     |
# |    n_updates            | 1760         |
# |    policy_gradient_loss | -0.00711     |
# |    value_loss           | 0.0231       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 1549        |
# |    iterations           | 90          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.015568649 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.154       |
# |    entropy_loss         | -0.403      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.000772    |
# |    loss                 | -0.0051     |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 0.0324      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 1554         |
# |    iterations           | 91           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 23296        |
# | train/                  |              |
# |    approx_kl            | 0.0025765616 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.154        |
# |    entropy_loss         | -0.412       |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.00077      |
# |    loss                 | -0.00253     |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 0.0381       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | 156          |
# | time/                   |              |
# |    fps                  | 1558         |
# |    iterations           | 92           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0093084425 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.153        |
# |    entropy_loss         | -0.394       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.000767     |
# |    loss                 | 0.0288       |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 0.093        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 156        |
# |    ep_rew_mean          | 156        |
# | time/                   |            |
# |    fps                  | 1563       |
# |    iterations           | 93         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 23808      |
# | train/                  |            |
# |    approx_kl            | 0.03376945 |
# |    clip_fraction        | 0.249      |
# |    clip_range           | 0.153      |
# |    entropy_loss         | -0.383     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.000764   |
# |    loss                 | 0.0013     |
# |    n_updates            | 1840       |
# |    policy_gradient_loss | -0.0127    |
# |    value_loss           | 0.0459     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 156         |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 1567        |
# |    iterations           | 94          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 24064       |
# | train/                  |             |
# |    approx_kl            | 0.026863191 |
# |    clip_fraction        | 0.379       |
# |    clip_range           | 0.152       |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.000762    |
# |    loss                 | -0.0306     |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.0284     |
# |    value_loss           | 0.0167      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 155        |
# |    ep_rew_mean          | 155        |
# | time/                   |            |
# |    fps                  | 1572       |
# |    iterations           | 95         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 24320      |
# | train/                  |            |
# |    approx_kl            | 0.01702563 |
# |    clip_fraction        | 0.182      |
# |    clip_range           | 0.152      |
# |    entropy_loss         | -0.357     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.000759   |
# |    loss                 | -0.015     |
# |    n_updates            | 1880       |
# |    policy_gradient_loss | -0.0137    |
# |    value_loss           | 0.0209     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 1576        |
# |    iterations           | 96          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.018916955 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.151       |
# |    entropy_loss         | -0.367      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.000757    |
# |    loss                 | 0.00157     |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.0049     |
# |    value_loss           | 0.0318      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 1580        |
# |    iterations           | 97          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 24832       |
# | train/                  |             |
# |    approx_kl            | 0.003984154 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.151       |
# |    entropy_loss         | -0.346      |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.000754    |
# |    loss                 | 0.00427     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.000924   |
# |    value_loss           | 0.0228      |
# -----------------------------------------
